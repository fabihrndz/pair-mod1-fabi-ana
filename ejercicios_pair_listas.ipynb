# %%
lista = [2, 4, 6, 8]

# %%
lista_2 = lista.copy()

# %%
print(lista_2)
# Out:
# [2, 4, 6, 8]

# %%
lista_def = (lista + lista_2)

# %%
print(lista_def)
# Out:
# [2, 4, 6, 8, 2, 4, 6, 8]

# %% [markdown]
# Ejercicio 2

# %%
lista1 = [1, 2, 3]

# %%
lista2 = [4, 5, 6]

# %%
lista3 = (lista1 + lista2)

# %%
print(lista3)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
#ejercicio 3

# %%
suma = sum(lista3[0:])

# %%
print(suma)
# Out:
# 21

# %% [markdown]
# ejercicio 4

# %%
max(lista3)
# Out:
# 6

# %% [markdown]
# ejercicio 5

# %%
len(lista3)
# Out:
# 6

# %% [markdown]
# ejercicio 6

# %%
lista3.index(4)
# Out:
# 3

# %% [markdown]
# ejercicio 7

# %%
lista3.count(2)
# Out:
# 1

# %% [markdown]
# ejercicio 8

# %%
lista4 = lista3[2:5]

# %%
print(lista4)
# Out:
# [3, 4, 5]

# %% [markdown]
# ejercicio 9

# %%
print(lista3)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
lista3[-1]
# Out:
# 6

# %% [markdown]
# ejercicio 11

# %%
lista5 = (lista3[1:3])

# %%
print(lista5)
# Out:
# ['7', 3]

# %% [markdown]
# ejercico 12

# %%
lista3[1] = "7"

# %% [markdown]
# ejercicio 13

# %%
print(lista_def)
# Out:
# [2, 4, 6, 8, 2, 4, 6, 8]

# %%
lista_inv = lista_def.copy()

# %%
print(lista_inv)
# Out:
# [2, 4, 6, 8, 2, 4, 6, 8]

# %%
lista_inv.reverse()

# %%
print(lista_inv)
# Out:
# [8, 6, 4, 2, 8, 6, 4, 2]

# %% [markdown]
# ejercicio 14

# %%
print(lista_def)
# Out:
# [2, 4, 6, 8, 2, 4, 6, 8]

# %%
lista_def.sort()

# %%
print(lista_def)
# Out:
# [2, 2, 4, 4, 6, 6, 8, 8]

# %% [markdown]
# TUPLAS

# %% [markdown]
# ejercicio 1

# %%
tupla = (1,2,3,4,5,6,3,1,9)

# %%
print(tupla[0])
# Out:
# 1

# %% [markdown]
# ejercicio 2

# %%
print(tupla[-1])
# Out:
# 9

# %% [markdown]
# ejercicio 3

# %%
len(tupla)
# Out:
# 9

# %% [markdown]
# ejercicio 4

# %%
tupla1 = (2,6,9,4,3,2,5,8,6)

# %%
tupla_def = tupla + tupla1

# %%
print(tupla_def)
# Out:
# (1, 2, 3, 4, 5, 6, 3, 1, 9, 2, 6, 9, 4, 3, 2, 5, 8, 6)

# %% [markdown]
# ejercicio 5

# %%
tupla_def.index(6)
# Out:
# 5

# %% [markdown]
# ejercicio 6

# %%
tupla_def.count(1)
# Out:
# 2

# %% [markdown]
# ejercicio 7

# %%
tupla_def[1:3]
# Out:
# (2, 3)

# %% [markdown]
# ejercicio 7

# %%
tupla_inv = tuple(reversed(tupla_def))

# %%
print(tupla_inv)
# Out:
# (6, 8, 5, 2, 3, 4, 9, 6, 2, 9, 1, 3, 6, 5, 4, 3, 2, 1)
