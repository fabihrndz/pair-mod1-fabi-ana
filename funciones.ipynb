# %%
#Contar la cantidad de caracteres en una cadena.

#Descripción: Crea una función llamada contar_caracteres que tome una cadena como parámetro y devuelva la cantidad de caracteres que contiene.

# %%
def contar_caracteres(cadena):
        
    return len(cadena)

cad = "hola, apuesto que no nos funciona"
resultado = contar_caracteres(cad)
print(resultado)
# Out:
# 33

# %%
def contar_caracteres(cadena):
    contador = 0
    for c in cadena:
        contador += 1
    return contador

cad = "hola, apuesto que no nos funciona"
print(contar_caracteres(cad))
# Out:
# 33

# %%
#Crear un diccionario con información de una persona.

#Descripción: Crea una función llamada crear_persona que tome como argumentos clave-valor los datos de una persona, como nombre, edad, ciudad, etc., y devuelva un diccionario con toda la información ingresada.

# %%
def crear_persona (ar, **kwargs):
    return ar.items()

# %%
info = {"nombre": "Ana", "edad": 30, "cuidad": "Malaga"}
crear_persona({"nombre": "Ana", "edad": 30, "cuidad": "Malaga"})
# Out:
# dict_items([('nombre', 'Ana'), ('edad', 30), ('cuidad', 'Malaga')])

# %%
def crear_persona(**kwargs):
    return kwargs


persona = crear_persona(
    nombre="Ana",
    edad=30,
    ciudad="Malaga")
print(persona)
# Out:
# {'nombre': 'Ana', 'edad': 30, 'ciudad': 'Malaga'}

# %%
#Encontrar el número que falta en una lista ordenada de números consecutivos.

#Descripción: Crea una función llamada encontrar_numero_faltante que tome una lista de números consecutivos (del 1 al N, sin repetir) con un número faltante y devuelva ese número faltante.

# %%
def encontrar_numero_faltante(lista):
    for e in lista:
    return e != e+1
    
variable = 1,2,3,5,6,7
print(encontrar_numero_faltante(variable))
# Out:
#   Cell In[33], line 3
#     return e != e+1
#     ^
# IndentationError: expected an indented block after 'for' statement on line 2

# %%
def encontrar_numero_faltante(lista):
    for e in lista:
        if e + 1 not in lista:
            return e + 1
res = encontrar_numero_faltante(variable)
print(res)
# Out:
# 4

# %%
#Encontrar el elemento duplicado en una lista de números.

#Descripción: Crea una función llamada encontrar_duplicado que tome una lista de números enteros y devuelva el elemento que está duplicado en la lista.

# %%
def encontrar_duplicado(lista):
    for el in lista:
        if el == el
            return el
        
dup = encontrar_duplicado([1,2,3,4,5,6,4])
print(dup)
# Out:
# 1

# %%
def encontrar_duplicado(lista):
    vistos = []

    for el in lista:
        if el in vistos:
            return el
        vistos.append(el)
dup = encontrar_duplicado([1,2,3,4,5,6,4])
print(dup)
# Out:
# 4
